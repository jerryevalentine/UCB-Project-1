# %% [markdown]
# # UCB Project 1 #
#
# ## Datasets ##
#
# ### Prefered dataset ###
# - We will first need to determine the feasibility of using the car sales dataset.
# - Need to check for nulls and use regular expressions to search for any garbage (corrupt data, data that should not be in the cell, etc.).  If the car sales is not appropriate then we will evaluate the credit card fraud dataset.
# - Note the dataset has a 10 usability score, which I believe is the highest.  This notebook is for due dillegence and also providing the metadata for the dataset.
#
# -https://www.kaggle.com/datasets/syedanwarafridi/vehicle-sales-data/data
#
# -https://www.kaggle.com/datasets/kelvinkelue/credit-card-fraud-prediction
#
# ## Criteria for inclusion: ##
# -Sufficiently large (558,837 records)
# -Loads in about 15 seconds on mny computer
# -11% of the Transmission records are null
#
#
# -https://www.kaggle.com/code/yusupibrahim/selling-price-predic-with-stacked-gen-r2-0-96 provides good example code

# %%
import pandas as pd

str_path_file = "data/car_prices.csv"

# Read the CSV file into a DataFrame
df_car_prices = pd.read_csv(str_path_file)
df_car_prices.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
#Data is 558,837 records
int_df_length = len(df_car_prices)
int_df_length
# Out:
# 558837

# %%
non_null_counts = df_car_prices.count()
print(f"Number of Non-null Values in Each Column, given {int_df_length} records:")
non_null_counts
# Out:
# Number of Non-null Values in Each Column, given 558837 records:
# year            558837
# make            548536
# model           548438
# trim            548186
# body            545642
# transmission    493485
# vin             558833
# state           558837
# condition       547017
# odometer        558743
# color           558088
# interior        558088
# seller          558837
# mmr             558799
# sellingprice    558825
# saledate        558825
# dtype: int64

# %%
# Count missing values in each column
missing_values = df_car_prices.isnull().sum()
print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df_car_prices.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df_car_prices.dtypes
data_types = df_car_prices.dtypes
print("Data Types of Columns:")
print(data_types)
# Out:
# Data Types of Columns:
# year              int64
# make             object
# model            object
# trim             object
# body             object
# transmission     object
# vin              object
# state            object
# condition       float64
# odometer        float64
# color            object
# interior         object
# seller           object
# mmr             float64
# sellingprice    float64
# saledate         object
# dtype: object

# %%
#Create an index of column names and display
str_car_prices = df_car_prices.columns
print("Column Names:", str_car_prices)
# Out:
# Column Names: Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
non_null_counts = df_car_prices.count()
print("Number of Non-null Values in Each Column:")
print(non_null_counts)
# Out:
# Number of Non-null Values in Each Column:
# year            558837
# make            548536
# model           548438
# trim            548186
# body            545642
# transmission    493485
# vin             558833
# state           558837
# condition       547017
# odometer        558743
# color           558088
# interior        558088
# seller          558837
# mmr             558799
# sellingprice    558825
# saledate        558825
# dtype: int64

# %%
#Unique values
str_column_name = "make"
unique_values = {column: df_car_prices[str_column_name].unique()}
print("Unique Values in Each Column:")
for column, values in unique_values.items():
    print(column + ":", values)
# Out:
# Unique Values in Each Column:
# saledate: ['Kia' 'BMW' 'Volvo' 'Nissan' 'Chevrolet' 'Audi' 'Ford' 'Hyundai' 'Buick'
#  'Cadillac' 'Acura' 'Lexus' 'Infiniti' 'Jeep' 'Mercedes-Benz' 'Mitsubishi'
#  'Mazda' 'MINI' 'Land Rover' 'Lincoln' 'lincoln' 'Jaguar' 'Volkswagen'
#  'Toyota' 'Subaru' 'Scion' 'Porsche' nan 'bmw' 'Dodge' 'FIAT' 'Chrysler'
#  'ford' 'Ferrari' 'Honda' 'GMC' 'mitsubishi' 'Ram' 'smart' 'chevrolet'
#  'Bentley' 'chrysler' 'pontiac' 'Pontiac' 'Saturn' 'Maserati' 'Mercury'
#  'HUMMER' 'landrover' 'cadillac' 'land rover' 'mercedes' 'mazda' 'toyota'
#  'lexus' 'gmc truck' 'honda' 'nissan' 'porsche' 'Saab' 'Suzuki' 'dodge'
#  'subaru' 'Oldsmobile' 'oldsmobile' 'hyundai' 'jeep' 'Isuzu' 'dodge tk'
#  'Geo' 'acura' 'volkswagen' 'suzuki' 'kia' 'audi' 'Rolls-Royce' 'gmc'
#  'maserati' 'mazda tk' 'mercury' 'buick' 'hyundai tk' 'mercedes-b' 'vw'
#  'Daewoo' 'chev truck' 'ford tk' 'plymouth' 'Plymouth' 'ford truck'
# ...

# %%
#Number of unique values
unique_counts = df_car_prices.nunique()
print("Number of Unique Values in Each Column:")
print(unique_counts)
# Out:
# Number of Unique Values in Each Column:
# year                34
# make                96
# model              973
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate          3766
# dtype: int64

# %%
df_car_prices.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
df_car_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
df_car_prices.nunique()
# Out:
# year                34
# make                96
# model              973
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate          3766
# dtype: int64

# %%
column_name = "null count"
#null_series = df_car_prices.isnull().sum()
#null_df = null_series.to_frame(name=column_name)
df.reset_index(drop=True, inplace=True)
#null_df['null_percent'] = ""
null_df['null_percent'] =(null_df['null count'] / 558837) * 100
null_df
# Out:
#               null count  null_percent
# year                   0      0.000000
# make               10301      1.843292
# model              10399      1.860829
# trim               10651      1.905922
# body               13195      2.361154
# transmission       65352     11.694287
# vin                    4      0.000716
# state                  0      0.000000
# condition          11820      2.115107
# odometer              94      0.016821
# color                749      0.134028
# interior             749      0.134028
# seller                 0      0.000000
# mmr                   38      0.006800
# sellingprice          12      0.002147
# saledate              12      0.002147

# %%
a.index.empty
# Out:
# False

# %%
null_df
# Out:
#               null count null_percent
# year                   0
# make               10301
# model              10399
# trim               10651
# body               13195
# transmission       65352
# vin                    4
# state                  0
# condition          11820
# odometer              94
# color                749
# interior             749
# seller                 0
# mmr                   38
# sellingprice          12
# saledate              12
