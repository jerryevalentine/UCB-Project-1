# %% [markdown]
# # UCB Project 1 (car_prices) #

# %%
import pandas as pd
import datetime
# When last runL Print current date and time

str_path_file = "Data/car_prices.csv"

# Read the CSV file into a DataFrame
df_car_prices = pd.read_csv(str_path_file)
print(datetime.datetime.now())
# Out:
# 2024-03-20 17:48:32.381690

# %%
df_car_prices.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df_car_prices.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
# Count missing values in each column
missing_values = df_car_prices.isnull().sum()
data_types = df_car_prices.dtypes
unique = df_car_prices.nunique()
non_null_counts = df_car_prices.count()

null_counts = df_car_prices.isnull().sum()
total_rows = len(df_car_prices)
null_percentage = (null_counts / total_rows) * 100

dataframe_metadata = pd.DataFrame({'Non-null Counts': non_null_counts, 'missing_values' :missing_values, 'null_percentage': null_percentage ,'Data Types': data_types, 'unique': unique})
dataframe_metadata
# Out:
#               Non-null Counts  missing_values  null_percentage Data Types  \
# year                   558837               0         0.000000      int64
# make                   548536           10301         1.843292     object
# model                  548438           10399         1.860829     object
# trim                   548186           10651         1.905922     object
# body                   545642           13195         2.361154     object
# transmission           493485           65352        11.694287     object
# vin                    558833               4         0.000716     object
# state                  558837               0         0.000000     object
# condition              547017           11820         2.115107    float64
# odometer               558743              94         0.016821    float64
# color                  558088             749         0.134028     object
# interior               558088             749         0.134028     object
# ...

# %% [markdown]
# # Below code needs to be run twice to work #

# %%
import pandas as pd
# When last runL Print current date and time
print(datetime.datetime.now())
#Needed to run twice to work.  Why?

# Convert 'saledate' to datetime object, ignoring errors
df_car_prices['saledate'] = pd.to_datetime(df_car_prices['saledate'], errors='coerce')

# Drop rows with invalid datetime values (NaT)
df_car_prices.dropna(subset=['saledate'], inplace=True)

# Extract year from 'saledate'
df_car_prices['saledate_year'] = df_car_prices['saledate'].dt.year

# Calculate age as the difference between 'year' and 'saledate_year'
df_car_prices['age'] = df_car_prices['saledate_year'] - df_car_prices['year']

# Drop 'saledate_year' column if not needed
df_car_prices.drop(columns=['saledate_year'], inplace=True)

# %%
df_car_prices.to_csv('data/clean_car_prices.csv', index=False)

# %%
#Filter by items to see duplicates, or any other data
make_value = 'Acura'
model_value = 'CL'
year_value = 1997

filtered_df = df_car_prices[(df_car_prices['make'] == make_value) &
                                     (df_car_prices['model'] == model_value) &
                                     (df_car_prices['year'] == year_value)]

display(filtered_df)
# Out:
#         year   make model         trim   body transmission                vin  \
# 29761   1997  Acura    CL          2.2  Coupe    automatic  19uya1247vl006813
# 49334   1997  Acura    CL  3.0 Premium  Coupe          NaN  19uya2257vl017017
# 49358   1997  Acura    CL            3  Coupe    automatic  19uya224xvl011025
# 131389  1997  Acura    CL  2.2 Premium  Coupe       manual  19uya1150vl018229
# 164065  1997  Acura    CL  2.2 Premium  Coupe       manual  19uya1152vl011623
# 234437  1997  Acura    CL  2.2 Premium  Coupe    automatic  19uya1259vl008474
# 234464  1997  Acura    CL          2.2  Coupe    automatic  19uya1249vl015397
# 275778  1997  Acura    CL  2.2 Premium  Coupe    automatic  19uya1258vl009485
# 290545  1997  Acura    CL  3.0 Premium  Coupe    automatic  19uya2259vl003409
# 293285  1997  Acura    CL  3.0 Premium  Coupe    automatic  19uya225xvl003306
# 354782  1997  Acura    CL  2.2 Premium  Coupe       manual  19uya1159vl021033
# ...
