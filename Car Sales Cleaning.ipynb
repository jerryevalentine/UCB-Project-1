# %%
import pandas as pd
import datetime
pd.set_option('display.max_columns', 500)
str_path_file = "Data/car_prices.csv"
df_car_prices = pd.read_csv(str_path_file)
int_original_df_length = len(df_car_prices)
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}")
# Out:
# Dataframe is 558837 rows, run at 2024-03-23 11:20:48.684041

# %% [markdown]
# # Nulls #

# %%
# Count missing values in each column
missing_values = df_car_prices.isnull().sum()
data_types = df_car_prices.dtypes
unique = df_car_prices.nunique()
non_null_counts = df_car_prices.count()

null_counts = df_car_prices.isnull().sum()
total_rows = len(df_car_prices)
null_percentage = (null_counts / total_rows) * 100

dataframe_metadata = pd.DataFrame({'Non-null Counts': non_null_counts, 'missing_values' :missing_values, 'null_percentage': null_percentage ,'Data Types': data_types, 'unique': unique})
print(datetime.datetime.now())
dataframe_metadata
# Out:
# 2024-03-23 11:20:51.853315
#               Non-null Counts  missing_values  null_percentage Data Types  \
# year                   558837               0         0.000000      int64
# make                   548536           10301         1.843292     object
# model                  548438           10399         1.860829     object
# trim                   548186           10651         1.905922     object
# body                   545642           13195         2.361154     object
# transmission           493485           65352        11.694287     object
# vin                    558833               4         0.000716     object
# state                  558837               0         0.000000     object
# condition              547017           11820         2.115107    float64
# odometer               558743              94         0.016821    float64
# color                  558088             749         0.134028     object
# interior               558088             749         0.134028     object
# seller                 558837               0         0.000000     object
# mmr                    558799              38         0.006800    float64
# sellingprice           558825              12         0.002147    float64
# saledate               558825              12         0.002147     object
#
#               unique
# year              34
# make              96
# model            973
# trim            1963
# body              87
# transmission       4
# vin           550297
# state             64
# condition         41
# odometer      172278
# color             46
# interior          17
# seller         14263
# mmr             1101
# sellingprice    1887
# saledate        3766

# %%
#Still need to be run twice?

#Extract year from sales date
df_car_prices=df_car_prices.loc[df_car_prices['saledate'].str.len()>5]
df_car_prices['saleyear']=df_car_prices['saledate'].str[11:15].astype('int')

# Drop rows with invalid datetime values (NaT)
df_car_prices.dropna(subset=['saledate'], inplace=True)

# Calculate age as the difference between 'year' and 'saledate_year'
df_car_prices['age'] = df_car_prices['saleyear'] - df_car_prices['year']

print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
# Out:
# Dataframe is 558799 rows, run at 2024-03-23 11:20:53.642321.  Original length 558837.

# %%
df_car_prices=df_car_prices.loc[~df_car_prices['odometer'].isnull()]
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
# Out:
# Dataframe is 558705 rows, run at 2024-03-23 11:20:53.974447.  Original length 558837.

# %%
#Clean body by making all characters lowercase
df_car_prices['body']=df_car_prices['body'].str.lower()
df_car_prices['make']=df_car_prices['make'].str.lower()
df_car_prices['model']=df_car_prices['model'].str.lower()
df_car_prices['trim']=df_car_prices['trim'].str.lower()
df_car_prices['state']=df_car_prices['state'].str.lower()
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
# Out:
# Dataframe is 558705 rows, run at 2024-03-23 11:20:55.616519.  Original length 558837.

# %%
#unique_body = df_car_prices['body'].nunique()

# %%
#Drop all rows where even one record is null
df_car_prices.dropna(inplace=True)
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
# Out:
# Dataframe is 472325 rows, run at 2024-03-23 11:20:56.736955.  Original length 558837.

# %%
df_car_prices['pct_mmr']=df_car_prices['sellingprice']/df_car_prices['mmr']
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
df_car_prices.head(2)
# Out:
# Dataframe is 472325 rows, run at 2024-03-23 11:20:56.770733.  Original length 558837.
#    year make    model trim body transmission                vin state  \
# 0  2015  kia  sorento   lx  suv    automatic  5xyktca69fg566472    ca
# 1  2015  kia  sorento   lx  suv    automatic  5xyktca69fg561319    ca
#
#    condition  odometer  color interior                   seller      mmr  \
# 0        5.0   16639.0  white    black  kia motors america  inc  20500.0
# 1        5.0    9393.0  white    beige  kia motors america  inc  20800.0
#
#    sellingprice                                 saledate  saleyear  age  \
# 0       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014   -1
# 1       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014   -1
#
#     pct_mmr
# 0  1.048780
# 1  1.033654

# %%
df_car_prices['age_when_sold'] = df_car_prices['saleyear'] - df_car_prices['year']
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
df_car_prices.head(2)
# Out:
# Dataframe is 472325 rows, run at 2024-03-23 11:20:57.031362.  Original length 558837.
#    year make    model trim body transmission                vin state  \
# 0  2015  kia  sorento   lx  suv    automatic  5xyktca69fg566472    ca
# 1  2015  kia  sorento   lx  suv    automatic  5xyktca69fg561319    ca
#
#    condition  odometer  color interior                   seller      mmr  \
# 0        5.0   16639.0  white    black  kia motors america  inc  20500.0
# 1        5.0    9393.0  white    beige  kia motors america  inc  20800.0
#
#    sellingprice                                 saledate  saleyear  age  \
# 0       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014   -1
# 1       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014   -1
#
#     pct_mmr  age_when_sold
# 0  1.048780             -1
# 1  1.033654             -1

# %%
df_car_prices['Make-Model'] = df_car_prices['make'] + '-' + df_car_prices['model']
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.")
df_car_prices.head(2)
# Out:
# Dataframe is 472325 rows, run at 2024-03-23 11:20:57.519278.  Original length 558837.
#    year make    model trim body transmission                vin state  \
# 0  2015  kia  sorento   lx  suv    automatic  5xyktca69fg566472    ca
# 1  2015  kia  sorento   lx  suv    automatic  5xyktca69fg561319    ca
#
#    condition  odometer  color interior                   seller      mmr  \
# 0        5.0   16639.0  white    black  kia motors america  inc  20500.0
# 1        5.0    9393.0  white    beige  kia motors america  inc  20800.0
#
#    sellingprice                                 saledate  saleyear  age  \
# 0       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014   -1
# 1       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)      2014   -1
#
#     pct_mmr  age_when_sold   Make-Model
# 0  1.048780             -1  kia-sorento
# 1  1.033654             -1  kia-sorento

# %%
# Count missing values in each column
missing_values = df_car_prices.isnull().sum()
data_types = df_car_prices.dtypes
unique = df_car_prices.nunique()
non_null_counts = df_car_prices.count()

null_counts = df_car_prices.isnull().sum()
total_rows = len(df_car_prices)
null_percentage = (null_counts / total_rows) * 100

dataframe_metadata = pd.DataFrame({'Non-null Counts': non_null_counts, 'missing_values' :missing_values, 'null_percentage': null_percentage ,'Data Types': data_types, 'unique': unique})
print(datetime.datetime.now())
dataframe_metadata
# Out:
# 2024-03-23 11:21:01.472328
#                Non-null Counts  missing_values  null_percentage Data Types  \
# year                    472325               0              0.0      int64
# make                    472325               0              0.0     object
# model                   472325               0              0.0     object
# trim                    472325               0              0.0     object
# body                    472325               0              0.0     object
# transmission            472325               0              0.0     object
# vin                     472325               0              0.0     object
# state                   472325               0              0.0     object
# condition               472325               0              0.0    float64
# odometer                472325               0              0.0    float64
# color                   472325               0              0.0     object
# interior                472325               0              0.0     object
# seller                  472325               0              0.0     object
# mmr                     472325               0              0.0    float64
# sellingprice            472325               0              0.0    float64
# saledate                472325               0              0.0     object
# saleyear                472325               0              0.0      int32
# age                     472325               0              0.0      int64
# pct_mmr                 472325               0              0.0    float64
# age_when_sold           472325               0              0.0      int64
# Make-Model              472325               0              0.0     object
#
#                unique
# year               26
# make               53
# model             764
# trim             1475
# body               45
# transmission        2
# vin            465768
# state              34
# condition          41
# odometer       160427
# color              20
# interior           17
# seller          11923
# mmr              1099
# sellingprice     1806
# saledate         3609
# saleyear            2
# age                27
# pct_mmr         34339
# age_when_sold      27
# Make-Model        772

# %%
#Note that the checksum in in Notebooks that use this data must match the checksum here.
df_car_prices.to_csv('Data/clean_car_prices.csv', index=False)
int_clean_car_prices_checksum = len(df_car_prices)
print(f"Dataframe is {len(df_car_prices)} rows, run at {datetime.datetime.now()}.  Original length {int_original_df_length}.  Clean Car Prices checksum is {int_clean_car_prices_checksum}")
# Out:
# Dataframe is 472325 rows, run at 2024-03-23 11:21:18.002660.  Original length 558837.  Clean Car Prices checksum is 472325
